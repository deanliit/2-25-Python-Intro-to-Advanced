# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course I - 7 weeks
# - Weekly Assignments - 20 hours - due next week Monday
# - 3 Class Quizzes
# - Step-by-tep class topic demos
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/2-25-Python-Intro-to-Advanced
#
# #Weekly Homework , Class Assignment, Class Project
#
# ### Class Quiz - Email link to google forms
# ### Weekly 20 hour Course Labs and Assignments email
#
# - practice examples from w3schools
# - examples from course book
#
# ## Python references
# - Course book

# %% [markdown]
# ## Python class - weekly assignment #5 - due next week Monday
# <pre>
#
# Reading Assignments:
# Python tutorial
#
# https://www.w3schools.com/python/default.asp
#
# -Python Dates
# -Python Math
# -Python Dictionary
# -Python Functions
#
# Assignment exercises
#
# Complete all of the exercises, display output from each exercises
# Optional create exercises in Google Colabs notebooks
# https://www.w3schools.com/python/python_examples.asp
#
# Create a google collabs notebooks
# Create code in vs.code
#
# Complete all of the exercises, display output from each exercises
#
# -Python Dates
# -Python Math
# -Python Dictionary
# -Python Functions
#
# </pre>

# %% [markdown]
# Introduction to Python
#
# https://www.w3schools.com/python/python_intro.asp
#
#
# <pre>
#
# ---------------------------------------------
# #Course I Module Summary
# -----------------------------------------------
#
# # Module 1
# ---------------------------
# Python fundamentals
# Data type
# Variables
# Input
# if, for, while loop
# Other
#
# # Module 2
# ----------------------------
# Array index
# Slicers, list comprehension
# Functions
# File input
# Other
#
# # Module 3
# --------------------------------
# Data structures
# Array, set, list, tuple, map
# Classes
# Lamda
# Other
#
# #optional - Module 4
# ---------------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
# Other
#
# </pre>

# %% [markdown]
# # demo invoice/inventory program
# # python console program , other python programs
#
# #Intro to Python
# - https://www.w3schools.com/python/python_intro.asp
# - input, casting, loop, if, other
# - other
#
# #Review course quiz ie:
# - 3 quizzes for course 1, approx. every 2 weeks
# - 1 week to complete quiz
# - quiz review before and after a quiz
# - 6 multiple choice and 1 fill-in coding

# %%
#other examples; input name, string length, uppercase, loop intro , array , if statement demo, other
#loop , range demo, array demo
#loops, for, while, nested loops

#week3-loop-demo-2.py

#indented code syntas - space or tabs
#: end of an expression
for i in range(1,10):
 #inside loop - any valid python code
 print("item: ", i)
 #tab, space alignment error
 #all code must be with the same indented mar
 # print("")
 for z in range(5):
    print("z: ", z)
# Out:
# item:  1
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  2
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  3
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  4
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  5
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  6
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  7
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  8
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4
# item:  9
# z:  0
# z:  1
# z:  2
# z:  3
# z:  4

# %%
#other examples; input name, string length, uppercase, loop intro , array , if statement demo, other
#loop , range demo, array demo
#loops, for, while, nested loops

#week3-loop-demo-3.py

#while (logical expression - true/false) exit loop
#logical error
# can have an endless loop if i is not incremented
#python used variable from cell above

i = 0
#or while(var1 not equal value1)
while i < 10:
 #true condition
 print("item: ", i)
 i = i + 1
else:
  #flase condiftion after loop completes
  print("loop complete")

if i == 10:
    print("loop completed=")
# Out:
# item:  0
# item:  1
# item:  2
# item:  3
# item:  4
# item:  5
# item:  6
# item:  7
# item:  8
# item:  9
# loop complete

# %%
#other examples; input name, string length, uppercase, loop intro , array , if statement demo, other
#loop , range demo, array demo

#week3-array-demo-3.py

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search
"""
arr1 = [1,6,34.7,36,346,37.18,6]
arr2 = ["item1","item2", 3, 5, 3]

print("")
print(arr1)
print("")

print("arr1 length: ", len(arr1))
print("arr2 length: ", len(arr2))

print("")

for i in arr1:
  print("item: ", i)

#access array index
#index out of bound
print("\n-- array index -- \n")
print("index-0 arr1: ", arr1[0])
print("index-1 arr1: ", arr1[1])
print("index-3 arr1: ", arr1[3])
#index out of bound
#print("index-10 arr1: ", arr1[10])
# Out:
# [1, 6, 34.7, 36, 346, 37.18, 6]
#
# arr1 length:  7
# arr2 length:  5
#
# item:  1
# item:  6
# item:  34.7
# item:  36
# item:  346
# item:  37.18
# item:  6
#
# -- array index --
#
# index-0 arr1:  1
# index-1 arr1:  6
# index-3 arr1:  36

# %%
#week3-demo-inv-app-2.py

"""

Write a program to compute total of twenty invoice/inventory items.
note: can use integer or float numbers
note: enter items into an array
note: prmopt for user email , convert email to uppercase
note: round to 2 decimal places

input example:
item1 -- 1
item2 -- ?
.....

output:

USER@EMAIL.COM
discount:
total :

#print("total: ", total)
#note: display other print formatting statements

"""

#array/list - store sequence/collection of data in memory referenced by a variable name
#examepl: arr1 = [1,6,34.7,36,346,37.18]
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists

items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

print(items)
print("\nitems length:", len(items))

#total = (items[0] + items[1] + items[2] + items[3]) #...item[4]....
total = 0
for i in items:
  total = total + i

email = input("email: ").upper()

rtotal = round(total,2)

print("\n email: ", email)
print("\n total: ", total)
print("\n round total: ", rtotal)

#input email
#round
# Out:
# [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
# items length: 20
# email: ann@gmail.com
#
#  email:  ANN@GMAIL.COM
#
#  total:  1030.5400000000002
#
#  round total:  1030.54

# %%
#compute percent

amount = 1000
percent = (10/100)
# module - % - remainder division

discount = (amount * percent)
total_discount = (amount - discount)
total_bonus = (amount + discount)

print("amount: ", amount)
print("discount: ", discount)
print("percent: ", percent, " = ", (percent*100))
print("percent total: ", total_discount)
print("bonus total: ", total_bonus)
# Out:
# amount:  1000
# discount:  100.0
# percent:  0.1  =  10.0
# percent total:  900.0
# bonus total:  1100.0

# %%
"""

Write a program to compute total of twenty invoice/inventory items.
note: can use integer or float numbers
note: enter items into an array
note: prmopt for user email , convert email to uppercase
note: round to 2 decimal places
note: if total is > 100 then apply 10% discount

input example:
item1 -- 1
item2 -- ?
.....

output:

USER@EMAIL.COM
discount:
total :

#print("total: ", total)
#note: display other print formatting statements

"""

# %% [markdown]
# #Data Structure introduction (array, list, set tuple, dict)
# - google classroom summay
#
# <pre>
# array = sequence/collection of [same data types], ie: same int, same float, etc.. ie:  [1,2,3,3,4,5]
# list = sequence/collection of can heva mixed or different data type , int and string, or int and boolean, other
#        can have duplicate values. ie: [1,2,3,3,4,5]
# tuple = read-only [list] , non updatable when created, also called, ie: (1,2,3,3,4,5)
# set = unique [list] of data, non duplicate list, 1,2,3,3,4,5 -- set generated by python =  {1,2,3,4,5}
# dict = key/value pair , key are unique, non duplicate: {key1:1,key2:5,item3:10}
#
# ------------
# #can contain duplicates, can contain unique values, can be read only
# #length of array, access index of an array
# #loop through array, access index, insert, update, delete, search, if exists
#
# -----------
#
# array/list = [1,2,3,3] #can contain duplicate
# tuple = (1,2,3,3) #read-only
# set = {1,2,3} # non  duplicate
# dict = {k1:1,k2:2,item3:3} #key , non duplicate
#
# </pre>

# %%
#Data Structure introduction (array, list, set tuple,, dict)

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists
"""

str_array_list = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#-- collection fundamentals - array/list,tuple,set,map

#length

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

#loop - for, while, list comprehension

#crud - create/insert, update, delete

#if item exist in collection - list/array,set,tuple,dict

#list comprehension - optimized way of looping on one line
#https://www.w3schools.com/python/python_lists_comprehension.asp

#------------------------------------------------------------------
#- for i in items
#- [for i in items] - write loop in 1 line
#use list comprehension instead of nested for loops

#slicers - extract a range of elements - optimized/optional/short hand way of
#- ie: range(1,10,2) - range(start,stop,skip)
#- ie: items[1:10:2] - start:stop:skip
#use slicers for nested lookup
#ie: extraing large number of sequence of itemsor nesting
#instead of using multiplie for loops use slicers
#example - used often in mathimatical, calculations , formulas, ai/ml

# %%
#Data Structure introduction (array, list, set tuple,, dict)
#week4-list-demo-1.py

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists
"""

title = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#-- collection fundamentals - array/list,tuple,set,map

print("")
print("title:",title)
print("items: \n", items)
print("")

#length
print("title length: ", len(title))
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print("title index=x", title[1]) #slicer[1:]
print("title index=x", title[4]) #slicers[4:]
print("items index=x", items[2]) #slicers[2:]
print("items index=x", items[5]) #slicers[5:]
print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

print("")
print("---negative index--")
print("")
print("title index=-1: ", title[-1]) #slicers=[-1:]
print("title index=-4: ", title[-4]) #slicers=[-4:]
print("items index=-2: ", items[-2]) #slicers=[-2:]
print("items index=-5: ", items[-5]) #slicers=[-5:]
print("")

#loop - for, while, list comprehension

#crud - create/insert, update, delete

#if item exist in collection - list/array,set,tuple,dict

#list comprehension - optimized way of looping on one line
#------------------------------------------------------------------
#- for i in items
#- [for i in items] - write loop in 1 line
#use list comprehension instead of nested for loops

#slicers - extract a range of elements - optimized/optional/short hand way of
#- ie: range(1,10,2) - range(start,stop,skip)
#- ie: items[1:10:2] - start:stop:skip
#use slicers for nested lookup
#ie: extraing large number of sequence of itemsor nesting
#instead of using multiplie for loops use slicers
#example - used often in mathimatical, calculations , formulas, ai/ml
# Out:
# title: intro to python
# items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
# title length:  15
# items length:  20
#
# title index=x n
# title index=x o
# items index=x 34.7
# items index=x 37.18

# %%
#Data Structure introduction (array, list, set tuple,, dict)
#week4-list-demo-2.py

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists
"""

title = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#-- collection fundamentals - array/list,tuple,set,map

print("")
print("title:",title)
print("items: \n", items)
print("")

#length
print("title length: ", len(title))
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print("title index=x", title[1])
print("title index=x", title[4])
print("items index=x", items[2])
print("items index=x", items[5])
print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

print("")
print("---negative index--")
print("")
print("title index=-1: ", title[-1]) #slicers=[-1:]
print("title index=-4: ", title[-4]) #slicers=[-4:]
print("items index=-2: ", items[-2]) #slicers=[-2:]
print("items index=-5: ", items[-5]) #slicers=[-5:]
print("")

#loop - for, while, list comprehension

#list comprehension - always return a list - can format new list output
#newlist = [ output for variable in array ]
#https://www.w3schools.com/python/python_lists_comprehension.asp

#crud - create/insert, update, delete

#if item exist in collection - list/array,set,tuple,dict

#list comprehension - optimized way of looping on one line
#https://www.w3schools.com/python/python_lists_comprehension.asp

#------------------------------------------------------------------
#- for i in items
#- [for i in items] - write loop in 1 line
#use list comprehension instead of nested for loops

#slicers - extract a range of elements - optimized/optional/short hand way of
#- ie: range(1,10,2) - range(start,stop,skip)
#- ie: items[1:10:2] - start:stop:skip
#use slicers for nested lookup
#ie: extraing large number of sequence of itemsor nesting
#instead of using multiplie for loops use slicers
#example - used often in mathimatical, calculations , formulas, ai/ml

# %%
#Data Structure introduction (array, list, set tuple,, dict)
#week4-list-demo-3.py

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists
"""

title = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#-- collection fundamentals - array/list,tuple,set,map

print("")
print("title:",title)
print("items: \n", items)
print("")

#length
print("title length: ", len(title))
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print("title index=1: ", title[1]) #slicers=[1:]
print("title index=4: ", title[4]) #slicers=[4:]
print("items index=2: ", items[2]) #slicers=[2:]
print("items index=5: ", items[5]) #slicers=[1:]
print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

print("")
print("---negative index--")
print("")
print("title index=-1: ", title[-1]) #slicers=[-1:]
print("title index=-4: ", title[-4]) #slicers=[-4:]
print("items index=-2: ", items[-2]) #slicers=[-2:]
print("items index=-5: ", items[-5]) #slicers=[-5:]
print("")

#loop - for, while, list comprehension
total = 0

for item in items:
  total += item

print("\items:\n ", items)
print("\n total: ", round(total,2))

#list comprehension - always return a list - can format new list output
#on a single line, can nest list comprehension, can also filter using if statement
#newlist = [ output for variable in array ]
#https://www.w3schools.com/python/python_lists_comprehension.asp

new_items = [item for item in items]
print("\n new_items: \n", new_items)

#crud - create/insert, update, delete - except tuple - read-only

#lookup
#if item exist in collection - list/array,set,tuple,dict

#list comprehension - optimized way of looping on one line
#------------------------------------------------------------------
#- for i in items
#- [for i in items] - write loop in 1 line
#use list comprehension instead of nested for loops

#slicers - extract a range of elements - optimized/optional/short hand way of
#- ie: range(1,10,2) - range(start,stop,skip)
#- ie: items[1:10:2] - start:stop:skip
#use slicers for nested lookup
#ie: extraing large number of sequence of itemsor nesting
#instead of using multiplie for loops use slicers
#example - used often in mathimatical, calculations , formulas, ai/ml
# Out:
# title: intro to python
# items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
# title length:  15
# items length:  20
#
# title index=1:  n
# title index=4:  o
# items index=2:  34.7
# items index=5:  37.18
#
#
# ---negative index--
#
# title index=-1:  n
# title index=-4:  t
# items index=-2:  53
# items index=-5:  18.22
#
# \items:
#   [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
#  total:  1030.54
#
#  new_items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]

# %%
#Data Structure introduction (array, list, set tuple,, dict)
#week4-list-demo-4.py

"""
#can contain duplicates, can contain unique values, can be read only
#length of array, access index of an array
#loop through array, access index, insert, update, delete, search, if exists
"""

title = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#-- collection fundamentals - array/list,tuple,set,map

print("")
print("title:",title)
print("items: \n", items)
print("")

#length
print("title length: ", len(title))
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print("title index=1: ", title[1]) #slicers=[1:]
print("title index=4: ", title[4]) #slicers=[4:]
print("items index=2: ", items[2]) #slicers=[2:]
print("items index=5: ", items[5]) #slicers=[1:]
print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

print("")
print("---negative index--")
print("")
print("title index=-1: ", title[-1]) #slicers=[-1:]
print("title index=-4: ", title[-4]) #slicers=[-4:]
print("items index=-2: ", items[-2]) #slicers=[-2:]
print("items index=-5: ", items[-5]) #slicers=[-5:]
print("")

#list/array/tuplte/set/dict
#loop - for, while, list comprehension
total = 0
for item in items:
  total += item

print("\items:\n ", items)
print("\n total: ", round(total,2))

#list comprehension - always return a list - can format new list output
#on a single line, can nest list comprehension, can also filter using if statement
#newlist = [ output for variable in array ]
#https://www.w3schools.com/python/python_lists_comprehension.asp

new_items = [item for item in items]
print("\n new_items: \n", new_items)

#crud - create/insert, update, delete - n/a - except tuple - read-only

#add - n/a - except tuple - read-only
items.append(87.23)

print("\n # add items len \n", len(items))

#update - n/a - except tuple - read-only
items[3] = 64.37

print("\n # update items - index - 3 \n", items[3])

#delete - n/a - except tuple - read-only
items.pop() #last item
items.remove(5) #search and remove item

print("\n # delete 2 items len \n", len(items))

#lookup
#if item exist in collection - list/array,set,tuple,dict
if 20 in items:
  print("\n # 20 found in items")
else:
  print("\n # 20 NOT found in items")

print("\items:\n ", items)
# Out:
# title: intro to python
# items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
# title length:  15
# items length:  20
#
# title index=1:  n
# title index=4:  o
# items index=2:  34.7
# items index=5:  37.18
#
#
# ---negative index--
#
# title index=-1:  n
# title index=-4:  t
# items index=-2:  53
# items index=-5:  18.22
#
# \items:
#   [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
#  total:  1030.54
#
#  new_items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
#  # add items len
#  21
#
#  # update items - index - 3
#  64.37
#
#  # delete 2 items len
#  19
#
#  # 20 found in items
# \items:
#   [1, 6, 34.7, 64.37, 346, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]

# %%
#week5-tuple-demo-1.py
#Data Structure introduction (array, list, set tuple,, dict)

#tuple is read-only
items = (1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34)

print("")
print("tuple items: \n", items)
print("")

#length
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print("items index=2: ", items[2]) #slicers=[2:]
print("items index=5: ", items[5]) #slicers=[1:]
print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

print("")
print("---negative index--")
print("")
print("items index=-2: ", items[-2]) #slicers=[-2:]
print("items index=-5: ", items[-5]) #slicers=[-5:]
print("")

total = 0

for item in items:
  total += item

print("\n total: ", round(total,2))

#list comprehension - always return a list - can format new list output
#https://www.w3schools.com/python/python_lists_comprehension.asp

new_items = [item for item in items]
print("\n new_items: \n", new_items)

#---- CRUD - CREATE/ADD/INSERT, UPDATE, DELETE ----
#- tuple - read only - can not CRUD

#add - n/a - except tuple - read-only
#items.append(87.23)

#print("\n # add items len \n", len(items))

#update - n/a - except tuple - read-only
#items[3] = 64.37

#print("\n # update items - index - 3 \n", items[3])

#delete - n/a - except tuple - read-only
#items.pop() #last item
#items.remove(5) #search and remove item

#print("\n # delete 2 items len \n", len(items))

#lookup
#if item exist in collection - list/array,set,tuple,dict
if 20 in items:
  print("\n # 20 found in items")
else:
  print("\n # 20 NOT found in items")


#convert a tuple to a list also: dict(), set()
list1 = list(items)
tuple1 = tuple(list1)

print("\n-- list1 -- \n", list1)
print("\n-- tuple1 -- \n", tuple1)
# Out:
# tuple items:
#  (1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34)
#
# items length:  20
#
# items index=2:  34.7
# items index=5:  37.18
#
#
# ---negative index--
#
# items index=-2:  53
# items index=-5:  18.22
#
#
#  total:  1030.54
#
#  new_items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
#  # 20 found in items
# -- list1 --
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
# -- tuple1 --
#  (1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34)

# %%
#week5-set-demo-1.py
#Data Structure introduction (array, list, set tuple,, dict)

#dictionary and set are used for fast lookup

#set - does not contain duplicates
#20 items - when set is created by python, python will remove duplicates
items = {1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34}

print("")
print("tuple items: \n", items)
print("")

#length - python will remove duplicates ie: less than 20 items
print("items length: ", len(items))
print("")

#index or slicers/slicing - n/a - set, dict
#https://www.w3schools.com/python/python_strings_slicing.asp

#
#set does not support indexers - conver set() to list() to access indexers
#
#print("items index=2: ", items[2]) #slicers=[2:]
#print("items index=5: ", items[5]) #slicers=[1:]
#print("")

#index or slicers/slicing - n/a - set, dict
#negative indexing

#
#set does not support indexers - conver set() to list() to access indexers
#
#print("")
#print("---negative index--")
#print("")
#print("items index=-2: ", items[-2]) #slicers=[-2:]
#print("items index=-5: ", items[-5]) #slicers=[-5:]
#print("")

total = 0

for item in items:
  total += item

print("\n total: ", round(total,2))

#list comprehension - always return a list - can format new list output
#https://www.w3schools.com/python/python_lists_comprehension.asp

new_items = [item for item in items]
print("\n new_items: \n", new_items)

#---- CRUD - CREATE/ADD/INSERT, UPDATE, DELETE ----

#add - n/a - except tuple - read-only
items.add(87.23)

#print("\n # add items len \n", len(items))

#update - n/a - set - - remove item the add item
#items[3] = 64.37

#print("\n # update items - index - 3 \n", items[3])

#delete -
items.remove(5) #search and remove item

print("\n # after delete len \n", len(items))

#lookup
#if item exist in collection - list/array,set,tuple,dict
if 20 in items:
  print("\n # 20 found in items")
else:
  print("\n # 20 NOT found in items")


#convert a tuple to a list also: dict(), set()
list1 = list(items)
tuple1 = tuple(list1)

print("\n-- list1 -- \n", list1)
print("\n-- tuple1 -- \n", tuple1)

# %%
#week4-slicers-demo-1.py

#indexers are not supported to set and dictionary
#can convert set or dict to list()
#can convert dict(), set() to list()

title = "string" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2]

#slicers demo #1
#(start:end-1:skip) = range(start,stop-1,skip)

#string-readonly-tuple-readonly,list, array - n/a set, map/dict
#https://www.w3schools.com/python/python_strings_slicing.asp

print(title)

#0   1   2   3   4   5 = lenght = 6
#s   t   r   i   n   g
#-6 -5  -4 - 3 - 2  -1

#positive slicers
print(f"\n [:] = {title[:]} \n")
print(f"\n [::2] = {title[::2]} \n")
print(f"\n [3:] {title[3:]} \n")

#negative slicers
print(f"\n [-1] = {title[-1]} \n")
print(f"\n [-5:-2] = {title[-5:-2]} \n")

#use case of slicers is to extract various range and compbine ranges
#A=from/to, B=from/to, C=from/to
#ie: (A + B + C)

#nested syntax - slicers and list comprehension ie: math/fomulas and algotrithms
#ie: pyton exam associate exam qusion: 2/3 level nesting list comprehension and slicers

#resverse list
list2 = list1[-1:1:-1]
print("\n",list2)
# Out:
# string
#
#  [:] = string
#
#
#  [::2] = srn
#
#
#  [3:] ing
#
#
#  [-1] = g
#
#
#  [-5:-2] = tri

# %%
#week4-list-comprehension-demo-1.py

title = "intro to python" #string is array/list - sequence of characters
items = [1,6,34.7,36,346,37.18,6,20,19,17,12.2,7,126.2,72,31.7,18.22,31,44,53,112.34]

#list comprehension demo #1
#list comprehension - always return a list - can format new list output
#newlist = [ output for variable in array ]
#can filter a list comprehension
#can have nested list comprehension [for x in y [for a in b]]

#https://www.w3schools.com/python/python_lists_comprehension.asp

new_items = [item for item in items]
print("\n new_items: \n", new_items)

list1 = [False for i in range(1,10)]
print("\n",list1)
# Out:
#  new_items:
#  [1, 6, 34.7, 36, 346, 37.18, 6, 20, 19, 17, 12.2, 7, 126.2, 72, 31.7, 18.22, 31, 44, 53, 112.34]
#
#  [False, False, False, False, False, False, False, False, False]
#
#  [False, False, False, False, False, False, False]
