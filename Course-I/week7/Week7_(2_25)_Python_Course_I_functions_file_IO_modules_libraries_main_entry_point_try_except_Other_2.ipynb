# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course I - 7 weeks
# - Weekly Assignments - 20 hours - due next week Monday
# - 3 Class Quizzes
# - Step-by-tep class topic demos
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/2-25-Python-Intro-to-Advanced
#
# ## Python references
# - Course book

# %% [markdown]
# ## Python Course I Weekly Class Assignment #7
# <pre>
#
# Reading Assignments:
#
# Python tutorial
# https://www.w3schools.com/python/default.asp
#
# Python PIP install
# import
# list, set, tuple, dictionary
# list comprehension
# String, slicers
# file input, output
#
# Assignment Exercises:
#
# Complete all of the exercises, display output from each exercises
# Optional create exercises in Google Colabs notebooks
#
# https://www.w3schools.com/python/python_examples.asp
#
# Create a google collabs notebooks
# Create code in vs.code
# Complete all of the exercises, display output from each exercises
#
#
# Python Course Book Chapter
# Beginner Exercises
#
# #2 - string, dictionary, loops
# #3 - functions, conditional statements, input
# #5 - file i/o, exception handling, string, input
# #7 - arithmetic, conditional statements, string manipulation
# #9 - loops, lists, functions
# #12 - string, loops, dictionary
# #14 - loops, arithmetic, string
# #16 - string, loops, slicing
# #17 - string, loops, dictionary
# #22 - lists, loops, sets
# #23 - lists, loops, min, max
# #24 - lists, sets, list comprehensions
# #26 - lists, loops, list comprehensions
# #28 - variables, tuples
#
# </pre>

# %% [markdown]
# Introduction to Python
#
# https://www.w3schools.com/python/python_intro.asp
#
#
# <pre>
#
# ---------------------------------------------
# #Course I Module Summary
# -----------------------------------------------
#
# # Module 1
# ---------------------------
# Python fundamentals
# Data type
# Variables
# Input
# if, for, while loop
# Other
#
# # Module 2
# ----------------------------
# Array index
# Slicers, list comprehension
# Functions
# File input
# Other
#
# # Module 3
# --------------------------------
# Data structures
# Array, set, list, tuple, map
# Classes
# Lamda
# Other
#
# #optional - Module 4
# ---------------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
# Other
#
# </pre>

# %%
#-- weekly topic summary
#
#import-datetime-
#min-max-sum-map-
#radnom-
#functions-
#file-IO-
#modules-libraries-
#main-entry-point-
#try-except
#Other

# %%
#functions-demo-1.py
#https://www.w3schools.com/python/python_functions.asp

#ambiguity - logical error - python keyword , also: min, max, etc
#not reccomended
#solution: ctraete function in class or custom library
#myclass.print, mylib.sum
"""
def print():`
  return f"my print: "
"""

#define function - function parameters
def square(number):
  return number * number

def func1():
  print("# funct1")

def func2(item):
  print("# funct2, ", item)

#return value , default paramater
def func3(item = "a"):
  return f"# funct3:  {item}"

#call function

print("square: ", square(10))
func1()
func2("itema")
print("func3: ", func3())
print("func3: ", func3("itemb"))
# Out:
# square:  100
# # funct1
# # funct2,  itema
# func3:  # funct3:  a
# func3:  # funct3:  itemb

# %%
#functions-demo-2.py
#https://www.w3schools.com/python/python_functions.asp

#all parameters are requred
def func1(a,b,c):
  print("funct1: a: ",a,",b: ",b,", c:",c)

#========================
#optional/required rule
#========================
#a,b = requred, c = optional - default value will be used
#last paramater can be optional when previous praramers are requred
def func2(a,b,c=3):
  print("func2: a: ",a,",b: ",b,", c:",c)

#a=optopnal,b,c = required
#error = last paramater must be required if previous paramater are optional or includes default parametrs
#error = last paramater can not be optinal  if previous paramater are optional or includes default parametrs
#def func3(a=1,b,c): #error
#def func3(a=1,b=2,c): #error
#def func3(a=1,b,c=3): #error
def func3(a=1,b=2,c=3): #no error
  print("func2: a: ",a,",b: ",b,", c:",c)

#all parameters are required
#func1()
func1("a1","b1","c1")

#a,b = required, c=optional
func1("a1","b1")

func3()

# %%
#input, output
#binary or text mode
#w3schools file management

#write - append, create new
#- each byte/character, each line, all

#read - each byte/character, each line, all

# %%
#file-io.demo-1.py
#w3schools file management

"""
function
try/except

--------------
read and parse invoice data file

invoice-1.txt
-------------------
12.8
32.7
89.45
45.8
23.67

invoice-2.csv.txt
-------------------
name, price
itema, 12.8
itemb, 32.7
itemc, 89.45
itemd, 45.8
iteme, 23.67

"""

#write - append, create new
#- each byte/character, each line, all

f = open("file1.txt", "a") #a = append, text mode or w - create new file
f.write("demo file 1 - ilne one  ") #add new line \n
f.write("line two") #add new line \n
f.close()

print("\n--- file1.txt created -- ")

f = open("file2.txt", "w") #write new file - a = append,
f.write("demo file 2 - ilne one \n")
f.write("line two \n")
f.close()

print("\n--- file2.txt created -- ")
# Out:
# --- file1.txt created --
#
# --- file2.txt created --

# %%
#file-io.demo-2.py
#w3schools file management


"""
function
try/except

--------------
read and parse invoice data file

invoice-1.txt
-------------------
12.8
32.7
89.45
45.8
23.67

invoice-2.csv.txt
-------------------
name, price
itema, 12.8
itemb, 32.7
itemc, 89.45
itemd, 45.8
iteme, 23.67


"""

print("\n-- read file1.txt \n")
#read - each byte/character, each line, all
f = open("file1.txt", "r") #text mode
print(f.read())
f.close()

print("\n-- read file2.txt \n")
f = open("file2.txt", "r") #text mode
print(f.read())
f.close()
# Out:
# -- read file1.txt
#
# demo file 1 - ilne one  line twodemo file 1 - ilne one  line two
#
# -- read file2.txt
#
# demo file 2 - ilne one
# line two

# %%
#read-invoice-1.py

"""
function
try/except
"""

"""
create a function to read file and compute total
"""
print("\n-- read invoice-1.txt \n")
f = open("invoice-1.txt", "r") #text mode
print(f.read())
f.close()
# Out:
# -- read invoice-1.txt
#
# 12.8
# 32.7
# 89.45
# 45.8
# 23.6

# %%
#read-invoice-1-1.py

"""
function
try/except
"""

"""
create a function to read file and compute total
"""
print("\n-- read invoice-1.txt \n")
f = open("invoice-1.txt", "r") #text mode

#read each line
#compute total

total = 0.0
line = f.readline()

while line:
  print(line.strip())
  line = f.readline()

f.close()
# Out:
# -- read invoice-1.txt
#
# 12.8
# 32.7
# 89.45
# 45.8
# 23.6

# %%
#read-invoice-1-2.py

"""
function
try/except - previent program exit
"""

"""
create a function to read file and compute total
"""

total = 0.0

print("\n-- read invoice-1.txt \n")

#with closes file when complete

with open("invoice-1.txt", "r") as f:
  line = f.readline()
  while line:
    total += float(line.strip())
    print(line.strip())
    line = f.readline()

print("\n -- total --: ", total)
# Out:
# -- read invoice-1.txt
#
# 12.8
# 32.7
# 89.45
# 45.8
# 23.6
#
#  -- total --:  204.35

# %%
#read-invoice-2.py

"""
function
try/except - previent program exit
"""

"""
create a function to read file and compute total
"""


#ValueError: could not convert string to float: ' 23.6a'

_total = 0.0
_index = 0

print("\n-- read invoice-1.csv.txt \n")

#with closes file when complete

with open("invoice-2.csv.txt", "r") as f:
  line = f.readline()
  while line:
    print(line.strip())
    line = f.readline()
    if _index > 0:
      _row_array = line.strip().split(",")
      print("extract row data: ", _row_array)
      #_name = str(_row_array[0])
      #_price = str(_row_array[1]) ## error, unable to access undex
      #print("** row array len: ", len(_row_array))
      _i = 0
      _price = 0.0
      for item in _row_array:
          if _i == 1:
            #print(item)
            _price = float(item)
            _total += _price
            print("** price: ", _price)
          _i += 1
    _index += 1

print("\n -- total --: ", _total)
# Out:
# -- read invoice-1.csv.txt
#
# name, price
# itema, 12.8
# extract row data:  ['itemb', ' 32.7']
# ** price:  32.7
# itemb, 32.7
# extract row data:  ['itemc', ' 89.45']
# ** price:  89.45
# itemc, 89.45
# extract row data:  ['itemd', ' 45.8']
# ** price:  45.8
# itemd, 45.8
# extract row data:  ['iteme', ' 23.67']
# ** price:  23.67
# iteme, 23.67
# extract row data:  ['itemf', ' 23.6a']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9b8b8f54b720> in <cell line: 0>()
#      33           if _i == 1:
#      34             #print(item)
# ---> 35             _price = float(item)
#      36             _total += _price
#      37             print("** price: ", _price)
#
# ValueError: could not convert string to float: ' 23.6a'

# %%
#read-invoice-2-1.py

"""
function
try/except - previent program exit
"""

"""
create a function to read file and compute total
"""

"""

invoice-2.csv.txt
-------------------
name, price
itema, 12.8
itemb, 32.7
itemc, 89.45
itemd, 45.8
iteme, 23.67
itemf, 23.6a

ValueError: could not convert string to float: ' 23.6a'
== program exit
== exception handling, previents the program from exiting

"""

_total = 0.0
_index = 0

print("\n-- read invoice-1.csv.txt \n")

#with closes file when complete

try:

  with open("invoice-2.csv.txt", "r") as f:
    line = f.readline()
    while line:
      print(line.strip())
      line = f.readline()
      if _index > 0:
        _row_array = line.strip().split(",")
        print("extract row data: ", _row_array)
        #_name = str(_row_array[0])
        #_price = str(_row_array[1]) ## error, unable to access undex
        #print("** row array len: ", len(_row_array))
        _i = 0
        _price = 0.0
        for item in _row_array:
            if _i == 1:
              #print(item)
              _price = float(item)
              _total += _price
              print("** price: ", _price)
            _i += 1
      _index += 1

  print("\n -- total --: ", _total)

except Exception as ex:
  #previent program exit, catch, process error
  print("# program error #")
  print(ex)
# Out:
# -- read invoice-1.csv.txt
#
# name, price
# itema, 12.8
# extract row data:  ['itemb', ' 32.7']
# ** price:  32.7
# itemb, 32.7
# extract row data:  ['itemc', ' 89.45']
# ** price:  89.45
# itemc, 89.45
# extract row data:  ['itemd', ' 45.8']
# ** price:  45.8
# itemd, 45.8
# extract row data:  ['iteme', ' 23.67']
# ** price:  23.67
# iteme, 23.67
# extract row data:  ['itemf', ' 23.6a']
# # program error #
# could not convert string to float: ' 23.6a'

# %%
#read-invoice-2-2.py

"""
function
try/except - previent program exit
main entry-point
"""

def main():
  print("## program start ")

#pythion auto populate __name__ with = "main" = 1at file bering ran ,
#"file_name or module_name" ie: file being imported
print("__name__: ",__name__)

if __name__ == "__main__":
  main()
# Out:
# __name__:  __main__
# ## program start

# %%
#read-invoice-2-3.py

"""
function
try/except - previent program exit
main entry-point
"""

def main():
    print("## program start ")

    """
    function
    try/except - previent program exit
    """

    """
    create a function to read file and compute total
    """

    """

    invoice-2.csv.txt
    -------------------
    name, price
    itema, 12.8
    itemb, 32.7
    itemc, 89.45
    itemd, 45.8
    iteme, 23.67
    itemf, 23.6a

    ValueError: could not convert string to float: ' 23.6a'
    == program exit
    == exception handling, previents the program from exiting

    """

    _total = 0.0
    _index = 0

    print("\n-- read invoice-1.csv.txt \n")

    #with closes file when complete

    try:

        with open("data\invoice-2.csv.txt", "r") as f:
            line = f.readline()
            while line:
                print(line.strip())
                line = f.readline()
                if _index > 0:
                #function-extract-price from line
                #opt: move funtion into file
                    _row_array = line.strip().split(",")
                    print("extract row data: ", _row_array)
                    #_name = str(_row_array[0])
                    #_price = str(_row_array[1]) ## error, unable to access undex
                    #print("** row array len: ", len(_row_array))
                    _i = 0
                    _price = 0.0
                    for item in _row_array:
                        if _i == 1:
                            #print(item)
                            _price = float(item)
                            _total += _price
                            print("** price: ", _price)
                            _i += 1
                _index += 1

        print("\n -- total --: ", _total)

    except Exception as ex:
        #previent program exit, catch, process error
        print("# program error #")
        print(ex)



#pythion auto populate __name__ with = "main" = 1at file bering ran ,
#"file_name or module_name" ie: file being imported
print("__name__: ",__name__)

if __name__ == "__main__":
  main()

# %%
#read-invoice-2-4.py

"""
modules function
try/except - previent program exit
main entry-point

"""

#move function to external library / import library
def GetPriceComputeTotal(item_row):
    #_name = str(_row_array[0])
    #_price = str(_row_array[1]) ## error, unable to access undex
    #print("** row array len: ", len(_row_array))
    _total = 0.0
    _i = 0
    #refactor to list comprehension
    for item in item_row:
      if _i == 1:
          _total += float(item)
          _i += 1

    return _total

def main():
    print("## program start ")

    """
    function
    try/except - previent program exit

    invoice-2.csv.txt
    -------------------
    name, price
    itema, 12.8
    itemb, 32.7
    itemc, 89.45
    itemd, 45.8
    iteme, 23.67
    itemf, 23.6a

    ValueError: could not convert string to float: ' 23.6a'
    == program exit
    == exception handling, previents the program from exiting

    """

    _total = 0.0
    _index = 0

    print("\n-- read invoice-1.csv.txt \n")

    #with closes file when complete

    try:

        with open("invoice-2.csv.txt", "r") as f:
            line = f.readline()
            while line:
                print(line.strip())
                line = f.readline()
                if _index > 0:
                #function-extract-price from line
                #opt: move funtion into file
                    _row_array = line.strip().split(",")
                    print("extract row data: ", _row_array)
                    _total = GetPriceComputeTotal(_row_array)
                _index += 1

        print("\n -- total --: ", _total)

    except Exception as ex:
        #previent program exit, catch, process error
        print("# program error #")
        print(ex)



#pythion auto populate __name__ with = "main" = 1at file bering ran ,
#"file_name or module_name" ie: file being imported
print("__name__: ",__name__)

if __name__ == "__main__":
  main()
# Out:
# __name__:  __main__
# ## program start
#
# -- read invoice-1.csv.txt
#
# name, price
# itema, 12.8
# extract row data:  ['itemb', ' 32.7']
# itemb, 32.7
# extract row data:  ['itemc', ' 89.45']
# itemc, 89.45
# extract row data:  ['itemd', ' 45.8']
# itemd, 45.8
# extract row data:  ['iteme', ' 23.67']
# iteme, 23.67
# extract row data:  ['itemf', ' 23.6a']
# itemf, 23.6a
# extract row data:  ['']
#
#  -- total --:  0.0

# %%
#invoice_lib1.py

def GetPriceComputeTotal(item_row):
    #_name = str(_row_array[0])
    #_price = str(_row_array[1]) ## error, unable to access undex
    #print("** row array len: ", len(_row_array))
    _total = 0.0
    _i = 0
    #refactor to list comprehension
    for item in item_row:
      if _i == 1:
          _total += float(item)
          _i += 1

    return _total

# %%
#read-invoice-2-5.py

"""
function modules/import library
try/except - previent program exit
main entry-point

"""

#import invoice_lib1
#import invoice_lib1 as inv_lib1
from invoice_lib1 import GetPriceComputeTotal

#invoice-libr1.py
#move function to external library / import library
"""
def GetPriceComputeTotal(item_row):
    #_name = str(_row_array[0])
    #_price = str(_row_array[1]) ## error, unable to access undex
    #print("** row array len: ", len(_row_array))
    _total = 0.0
    _i = 0
    #refactor to list comprehension
    for item in item_row:
      if _i == 1:
          _total += float(item)
          _i += 1

    return _total
"""

def main():
    print("## program start ")

    """
    function
    try/except - previent program exit

    invoice-2.csv.txt
    -------------------
    name, price
    itema, 12.8
    itemb, 32.7
    itemc, 89.45
    itemd, 45.8
    iteme, 23.67
    itemf, 23.6a

    ValueError: could not convert string to float: ' 23.6a'
    == program exit
    == exception handling, previents the program from exiting

    """

    _total = 0.0
    _index = 0

    print("\n-- read invoice-1.csv.txt \n")

    #with closes file when complete

    try:

        with open("invoice-2.csv.txt", "r") as f:
            line = f.readline()
            while line:
                print(line.strip())
                line = f.readline()
                if _index > 0:
                #function-extract-price from line
                #opt: move funtion into file
                    _row_array = line.strip().split(",")
                    print("extract row data: ", _row_array)
                    #_total = invoice_lib1.GetPriceComputeTotal(_row_array)
                    #_total = inv_lib1.GetPriceComputeTotal(_row_array)
                    _total = GetPriceComputeTotal(_row_array)

                _index += 1

        print("\n -- total --: ", _total)

    except Exception as ex:
        #previent program exit, catch, process error
        print("# program error #")
        print(ex)



#pythion auto populate __name__ with = "main" = 1at file bering ran ,
#"file_name or module_name" ie: file being imported
print("__name__: ",__name__)

if __name__ == "__main__":
  main()
# Out:
# __name__:  __main__
# ## program start
#
# -- read invoice-1.csv.txt
#
# name, price
# itema, 12.8
# extract row data:  ['itemb', ' 32.7']
# itemb, 32.7
# extract row data:  ['itemc', ' 89.45']
# itemc, 89.45
# extract row data:  ['itemd', ' 45.8']
# itemd, 45.8
# extract row data:  ['iteme', ' 23.67']
# iteme, 23.67
# extract row data:  ['itemf', ' 23.6a']
# itemf, 23.6a
# extract row data:  ['']
#
#  -- total --:  0.0

# %%
#read-invoice-2-6.py

"""
function modules/import library
try/except - previent program exit
main entry-point
entry point parameter argument ie: program.py name@email.com 32528623
"""

#import invoice_lib1
#import invoice_lib1 as inv_lib1
from invoice_lib1 import GetPriceComputeTotal #, Other-Methods
import sys #retrieve paramater arguments

#invoice-libr1.py
#move function to external library / import library
"""
def GetPriceComputeTotal(item_row):
    #_name = str(_row_array[0])
    #_price = str(_row_array[1]) ## error, unable to access undex
    #print("** row array len: ", len(_row_array))
    _total = 0.0
    _i = 0
    #refactor to list comprehension
    for item in item_row:
      if _i == 1:
          _total += float(item)
          _i += 1

    return _total
"""

def main():
    print("## program start ")

    """
    function
    try/except - previent program exit

    invoice-2.csv.txt
    -------------------
    name, price
    itema, 12.8
    itemb, 32.7
    itemc, 89.45
    itemd, 45.8
    iteme, 23.67
    itemf, 23.6a

    ValueError: could not convert string to float: ' 23.6a'
    == program exit
    == exception handling, previents the program from exiting

    """

    _total = 0.0
    _index = 0

    print("\n-- read invoice-1.csv.txt \n")

    #with closes file when complete

    try:

        with open("invoice-2.csv.txt", "r") as f:
            line = f.readline()
            while line:
                print(line.strip())
                line = f.readline()
                if _index > 0:
                #function-extract-price from line
                #opt: move funtion into file
                    _row_array = line.strip().split(",")
                    print("extract row data: ", _row_array)
                    #_total = invoice_lib1.GetPriceComputeTotal(_row_array)
                    #_total = inv_lib1.GetPriceComputeTotal(_row_array)
                    _total = GetPriceComputeTotal(_row_array)

                _index += 1

        print("\n -- total --: ", _total)

    except Exception as ex:
        #previent program exit, catch, process error
        print("# program error #")
        print(ex)



#pythion auto populate __name__ with = "main" = 1at file bering ran ,
#"file_name or module_name" ie: file being imported
print("__name__: ",__name__)

if __name__ == "__main__":
  #retrieve paramater arguments
  if len(sys.argv) > 1:
    print("file-name:", sys.argv[0])
    print("agg-1: email:", sys.argv[1])
  main()

# %%
#review course book examples - beginner level exercises
#starting from page 43

#ex2. cout word frequency - combines loop, dict, split
