# %% [markdown]
# #Python Course II - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course II - 9 weeks
# - Weekly Assignments - 20 hours - due next week Monday
# - 3 Class Quizzes
# - 3 Data Analysis Quizzes - short data sql code example
# - Step-by-tep class topic demos
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/2-25-Python-Intro-to-Advanced
#
# ## Python references
# - Course book

# %% [markdown]
# ## Python Course II Weekly Class Assignment #1
# <pre>
#
# Reading Assignments:
#
# Python tutorial
# https://www.w3schools.com/python/default.asp
#
# Python File Handling
# Python Try Except
# Python Functions
# Assignment Exercises:
#
# Complete all of the exercises, display output from each exercises
# Optional create exercises in Google Colabs notebooks
#
# Create a google collabs notebooks
# Create code in vs.code
# Complete all of the exercises, display output from each exercises
#
# Python tutorial examples
# https://www.w3schools.com/python/python_examples.asp
#
#
# Python File Handling
# Python Try Except
# Python Functions
#
# Python Course Book Chapter
# Intermediate Exercises
#
#
#
# </pre>

# %% [markdown]
# Introduction to Python
#
# https://www.w3schools.com/python/python_intro.asp
#
#
# <pre>
#
# ---------------------------------------------
# #Course II Module Summary
# -----------------------------------------------
#
# Module #1
# - Git, GitHub introduction
# - Creating python command line applications
# - Python main app  __name__
# - Parameter array: *args, **kvargs
# - Import Modules
# - Error handling
# - pip install python-library-name
# - Course I review
# - Other
#
# Moduls #2
# - Python Data Analysis, EDA, ETL
# - Pandas
# - Graphs
# - SQL
# - Other
#
# Module #3
# - Class, OOP
# - Lamda
# - Other
#
# Module #4
# - Html introduction
# - Beautiful soup screen scraping
# - Other
#
# Module 5
# - Python ai, ml, npl introduction
# - PCAP Exam prep
# - Other
#
# </pre>

# %%
#-- weekly topic summary
#
#Git, Github
#Data Analysis
#Other

# %% [markdown]
# # Introduction to Git/github
#   - https://www.w3schools.com/git/default.asp
#
# # Github account
#  -  https://github.com
#
# ### Installing git command line tool
#   - https://git-scm.com/downloads

# %% [markdown]
# #Git/Github Summary
#
#
# <pre>
# <xmp>
# Introduction to git/github - used by 70%+ of industry
#
# - code repository
# - teams/developers can share code online
# - teams/developers modify same code without overwriting each others code
# - teams/developers - code collaboration
# - teams/developers - update code from command line
#
# https://www.w3schools.com/git/default.asp
#
# https://github.com
#   - online or command line
#  - preview other code
#  - download code
#  - upload code
#  - CRUD - create update and delete code online
#     - can preview or download other developer codes
#     - other developers code is readonly
#     - can not modify other developers code unless given permission by the other developers
#
# https://git-scm.com/downloads
#  - download git command line tool
#
# Main Command line github code / terms
# - Repository or Repo - online code workspace ie: online root folder
#
# Branch - git folder which maintains complete history of all git branch content modifications.
# git branch is a versioned history or snapshot of all modifications at a point in time.
# preview branch history command line: git log
#
# you can create many different versions of any branch
#
# github repositories can not contain empty folders/directories
# can add an empty file to a github repository folder/direcrtory
#
# - git config --global user.name
# - git config --global user.email
# - git clone github-repo
# - git add
# - git commit
# - git push
# - git pull
# - git status
# - git log --oneline
#
# </xmp>
# </pre>

# %% [markdown]
# ## Github online demo
# - intro to gighub online environment
#   - repositories, settings, other
# - creating a reportory
#   - public or private
#   - add readme file
# - create, update and delete files
# - download, upload files
# - github commit history
# - create empty folders with empty file
# - delete or re-name a repository ie: settings
# - clonging a repository
#
# #github repository urls
# - browser url
#   - https://github.com/deanliit/demo-repo-1
#
# - code repository ie: clone/copy code in vs.code
#   - https://github.com/deanliit/demo-repo-1.git

# %% [markdown]
# # clone a repository overview
# - create new github reporitory or use an exiiting repository
# - copy repository url
# - from command line ina root project folder
# - clone repository
# - cd into cloned-repository
# - access cloned repository from vs.code
#   - create, update, delet files/folders
#   - modify files
#
# - from vs.code command line of cloned-repository
#
# - initialize a github repository account - done 1 time
# - git config --global user.name "your-github-user-name"
# - git config --global user.email "your-github-user-email"
#
# - commit changes - git, add, commit
# - push/publishing changes from vs.code to github
#
# - pull latest changes
#
# - preview history
# - git log --oneline

# %% [markdown]
# #Clone github repository Demo
#
# <pre>
# <xmp>
#
# #install github command line utility
#
# #Git summary
# Repository - github project name
# Branch - github folder to store github update history
#
#
# # create repository ie: demorepo1
# # copy repo clone url ie:
#
#
# # goto vs.code command prompt
# # select a project folder ie: c:\liit-dev\gitclone-demo-1
#
# #clone repository ie: git url
#
# #git clone
#
# #initialize git user and email - done one time
#
# git config –global user.name “your-github-username”
# git config –global user.email “your-github-email”
#
# #make updates to cloned git repo
#
# git add .
# git commit -m “comment”
# Git push origin main
#
# # Preview updates
# git status
# git log
#
# </xmp>
# </pre>

# %% [markdown]
# #demo git clone class exercise - 1
# ---------------------------------------
# <pre>
# <xmp>
#
# 1. github repo clone demo
# - goto vs.vode project folder
#
# 2. non-cloned folder
# \course-ii\week1\git-clone-demo-1
#
# 3. goto command terminal of project-folder
#
# 4. clone repo
# git clone https://github.com/deanliit/demo-repo-2.git
#
# 5. cd into cloned folder
#
# 6. get and updated changes
#  - inside cloned folder
# git pull
#
# 7. preview history
#  - inside cloned folder
# git log --oneline
#
#
#
# </xmp>
# </pre>

# %% [markdown]
# #demo git clone class exercise - 2
# ---------------------------------------
# <pre>
# <xmp>
#
# 1. github repo clone demo
# - goto vs.vode project folder
#
# 2. non-cloned folder
# \course-ii\week1\git-clone-demo-1
#
# 3. goto command terminal of project-folder
#
# 4. clone repo
# git clone https://github.com/deanliit/demo-repo-2.git
#
# 5. cd into cloned folder
#
# 6. get and updated changes
#  - inside cloned folder
# git pull
#
# 7. preview history
#  - inside cloned folder
# git log --oneline
#
# 8. make updates to your owned github repo
# - inside cloned folder
# - initialize github account - step done 1 time
# - git config --global user.name "your-git-hub-username"
# - git config --global user.email "your-git-hub-email"
#
# 9. preview git accout info
# - inside cloned folder
# - git config --global user.name
# - git config --global user.email
#
# note: git will authenticate your account the first time you make updates
# 10. make local update and push changes to github repo
# - inside cloned folder
# - make updates in vs.code to files/folders
#
# git add .
# git commit -m "update 1"
# git push origin main
#
#
# </xmp>
# </pre>
